# %%
# !pwd
# Out:
# /Users/shawnguiter/Documents

# %%
import geopandas as gpd
fp = "/Users/shawnguiter/Downloads/Europe_borders/Europe_borders.shp"
data = gpd.read_file(fp)

# %%
data.crs
# Out:
# {'init': 'epsg:4326'}

# %%
data_proj = data.copy()

# %%
data_proj = data_proj.to_crs(epsg=3035)

# %%
data_proj['geometry'].head()
# Out:
# 0    POLYGON ((4221214.558088431 3496203.404338956,...
# 1    POLYGON ((4224860.478308966 2732279.319617757,...
# 2    POLYGON ((4104652.175545862 3390034.953002084,...
# 3    POLYGON ((4113025.664284974 3391895.755505159,...
# 4    POLYGON ((4115871.227627173 3395282.099288368,...
# Name: geometry, dtype: object

# %%
import matplotlib.pyplot as plt
data.plot(facecolor='gray');

# %%
plt.title("WGS84 projection");

# %%
plt.tight_layout()

# %%
data_proj.plot(facecolor='blue');

# %%
plt.title("ETRS Lambert Azimuthal Equal Area projection");

# %%
plt.tight_layout()

# %%
data.plot(facecolor='gray');

# Add title
plt.title("WGS84 projection");

# Remove empty white space around the plot
plt.tight_layout()

# %%
data_proj.plot(facecolor='blue');

# Add title
plt.title("ETRS Lambert Azimuthal Equal Area projection");

# Remove empty white space around the plot
plt.tight_layout()

# %%
# Projection Exercise
import geopandas as gpd
fp = "/Users/shawnguiter/Downloads/some_posts.csv"
data_posts = gpd.read_file(fp)

# %%
type(data_posts)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data_posts.head()
# Out:
#              lat           lon         timestamp    userid geometry
# 0  -24.980792492  31.484633302  2015-07-07 03:02  66487960     None
# 1  -25.499224667  31.508905612  2015-07-07 03:18  65281761     None
# 2  -24.342578456  30.930866066  2015-03-07 03:38  90916112     None
# 3   -24.85461393  31.519718439  2015-10-07 05:04  37959089     None
# 4  -24.921068894  31.520835558  2015-10-07 05:19  27793716     None

# %%
data_posts.plot()

# %%
# %matplotlib inline

# %%
data_posts.crs
# Out:
# {}
